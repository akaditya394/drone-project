# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov5n.pt')
# Out:
# PRO TIP 💡 Replace 'model=yolov5n.pt' with new 'model=yolov5nu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.

# %%
history = model.train(data="data.yaml", epochs=100)
# Out:
# Ultralytics YOLOv8.0.89 🚀 Python-3.10.6 torch-2.0.0+cu117 CUDA:0 (NVIDIA GeForce GTX 1050, 4039MiB)
# ...

# %%
results = model.val()
# Out:
# Ultralytics YOLOv8.0.89 🚀 Python-3.10.6 torch-2.0.0+cu117 CUDA:0 (NVIDIA GeForce GTX 1050, 4039MiB)
# YOLOv5n summary (fused): 193 layers, 2503334 parameters, 0 gradients, 7.1 GFLOPs
# val: Scanning /mnt/CODE/AI-ML/Object Detection/Birds-Drone/BirdVsDrone/yolov7/bd_data/valid/labels.cache... 97 images, 3 backgrounds, 0 corrupt: 100%|██████████| 100/100 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,  4.16it/s]
#                    all        100         97      0.814      0.628      0.709      0.412
#                   Bird        100         48      0.715      0.604      0.601      0.336
#                  Drone        100         49      0.914      0.652      0.818      0.488
# Speed: 1.4ms preprocess, 7.8ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to runs/detect/val

# %%
results
# Out:
# ultralytics.yolo.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1])
# box: ultralytics.yolo.utils.metrics.Metric object
# confusion_matrix: <ultralytics.yolo.utils.metrics.ConfusionMatrix object at 0x7f3b106566e0>
# fitness: 0.44158418388310816
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([    0.33579,     0.48789])
# names: {0: 'Bird', 1: 'Drone'}
# plot: True
# results_dict: {'metrics/precision(B)': 0.814362725676719, 'metrics/recall(B)': 0.628149336460347, 'metrics/mAP50(B)': 0.709272076155384, 'metrics/mAP50-95(B)': 0.4118410847417442, 'fitness': 0.44158418388310816}
# save_dir: PosixPath('runs/detect/val')
# speed: {'preprocess': 1.4290952682495117, 'inference': 7.840576171875001, 'loss': 0.0010704994201660156, 'postprocess': 1.1456918716430664}
